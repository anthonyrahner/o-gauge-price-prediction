# %%
# imports / initializations

import os
import requests
from ebaysdk.finding import Connection
import datetime
from ebaysdk.exception import ConnectionError

from dotenv import load_dotenv
load_dotenv()
API_KEY = os.getenv('api_key')
ACCESS_TOKEN = os.getenv('access_token') # temporary token for testing

# %%
# Test with Browse API
# Get JSON response for search of Lionel Reading T1s

url = "https://api.ebay.com/buy/browse/v1/item_summary/search"

params = {
    "q": "lionel reading t1",
    "limit": 3
}

headers = {
    "Authorization": f'Bearer {ACCESS_TOKEN}',
    "Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=params)

print("Status code:", response.status_code)
data = response.json()
data
# Out:
# Status code: 200
# {'href': 'https://api.ebay.com/buy/browse/v1/item_summary/search?q=lionel+reading+t1&limit=3&offset=0',
#  'total': 22,
#  'next': 'https://api.ebay.com/buy/browse/v1/item_summary/search?q=lionel+reading+t1&limit=3&offset=3',
#  'limit': 3,
#  'offset': 0,
#  'itemSummaries': [{'itemId': 'v1|397473412026|0',
#    'title': 'Lionel 6-18006 O Gauge Reading T-1 4-8-4 Steam Locomotive & Tender #2100 EX/Box',
#    'leafCategoryIds': ['262303'],
#    'categories': [{'categoryId': '262303', 'categoryName': 'Locomotives'},
#     {'categoryId': '220', 'categoryName': 'Toys & Hobbies'},
#     {'categoryId': '180250', 'categoryName': 'Model Railroads & Trains'},
#     {'categoryId': '262301', 'categoryName': 'Railroads & Trains'}],
#    'image': {'imageUrl': 'https://i.ebayimg.com/images/g/6yoAAeSw8s9pcsBq/s-l225.jpg'},
#    'price': {'value': '387.99', 'currency': 'USD'},
#    'itemHref': 'https://api.ebay.com/buy/browse/v1/item/v1%7C397473412026%7C0',
#    'seller': {'username': 'trainz',
#     'feedbackPercentage': '99.8',
#     'feedbackScore': 730482},
#    'condition': 'Used',
#    'conditionId': '3000',
#    'thumbnailImages': [{'imageUrl': 'https://i.ebayimg.com/images/g/6yoAAeSw8s9pcsBq/s-l1600.jpg'}],
#    'shippingOptions': [{'shippingCostType': 'FIXED',
#      'shippingCost': {'value': '27.11', 'currency': 'USD'},
#      'minEstimatedDeliveryDate': '2026-02-02T08:00:00.000Z',
#      'maxEstimatedDeliveryDate': '2026-02-05T08:00:00.000Z'}],
#    'buyingOptions': ['FIXED_PRICE'],
#    'epid': '1800681694',
#    'itemWebUrl': 'https://www.ebay.com/itm/397473412026?_skw=lionel+reading+t1&hash=item5c8b42f3ba:g:6yoAAeSw8s9pcsBq',
#    'itemLocation': {'postalCode': '305**', 'country': 'US'},
#    'additionalImages': [{'imageUrl': 'https://i.ebayimg.com/images/g/xN4AAeSwiLRpcsBq/s-l225.jpg'},
#     {'imageUrl': 'https://i.ebayimg.com/images/g/DVUAAeSw-3lpcsBq/s-l225.jpg'},
#     {'imageUrl': 'https://i.ebayimg.com/images/g/xOEAAeSwiLRpcsBq/s-l225.jpg'},
#     {'imageUrl': 'https://i.ebayimg.com/images/g/6FYAAeSwyztpcsBq/s-l225.jpg'},
#     {'imageUrl': 'https://i.ebayimg.com/images/g/xOAAAeSwiLRpcsBq/s-l225.jpg'},
#     {'imageUrl': 'https://i.ebayimg.com/images/g/7OwAAeSwrptpcsBq/s-l225.jpg'},
#     {'imageUrl': 'https://i.ebayimg.com/images/g/vyAAAeSwemNpcsBq/s-l225.jpg'}],
#    'adultOnly': False,
#    'legacyItemId': '397473412026',
#    'availableCoupons': False,
#    'itemOriginDate': '2026-01-07T21:23:46.000Z',
#    'itemCreationDate': '2026-01-07T21:23:46.000Z',
#    'topRatedBuyingExperience': False,
#    'priorityListing': False,
#    'listingMarketplaceId': 'EBAY_US'},
#   {'itemId': 'v1|389507354687|0',
#    'title': '(PRE ORDER) Lionel Reading Legacy T1 #2114',
#    'leafCategoryIds': ['262303'],
#    'categories': [{'categoryId': '262303', 'categoryName': 'Locomotives'},
#     {'categoryId': '220', 'categoryName': 'Toys & Hobbies'},
#     {'categoryId': '180250', 'categoryName': 'Model Railroads & Trains'},
#     {'categoryId': '262301', 'categoryName': 'Railroads & Trains'}],
#    'image': {'imageUrl': 'https://i.ebayimg.com/images/g/TSoAAeSw7nhpa-Bq/s-l225.jpg'},
#    'price': {'value': '1.00', 'currency': 'USD'},
#    'itemHref': 'https://api.ebay.com/buy/browse/v1/item/v1%7C389507354687%7C0',
#    'seller': {'username': 'troystrainshop',
#     'feedbackPercentage': '100.0',
#     'feedbackScore': 610},
#    'condition': 'New',
#    'conditionId': '1000',
#    'thumbnailImages': [{'imageUrl': 'https://i.ebayimg.com/images/g/TSoAAeSw7nhpa-Bq/s-l1600.jpg'}],
#    'shippingOptions': [{'shippingCostType': 'FIXED',
#      'shippingCost': {'value': '0.00', 'currency': 'USD'},
#      'minEstimatedDeliveryDate': '2026-03-20T07:00:00.000Z',
#      'maxEstimatedDeliveryDate': '2026-04-14T07:00:00.000Z'}],
#    'buyingOptions': ['FIXED_PRICE'],
#    'itemWebUrl': 'https://www.ebay.com/itm/389507354687?_skw=lionel+reading+t1&hash=item5ab072903f:g:TSoAAeSw7nhpa-Bq&amdata=enc%3AAQALAAAA8DZq0hFgvSYlgrFkWCFZ3z0A3SoSaAkPvFPJ3dQXG1FHhA59X2Ms%2FGMj6pkbmSNB%2FfmurlAYdrn%2F6Tz8o5juzKPt8M30AyxKak8FoQudEHqCqujbPeahBp%2B4c4ED9DASe1c%2FCZwbV%2FqLsrp2miJrVXAvHj3XyPl9yiuiaGhBziUT2Q0sns4n8aHCks%2FAHzBRCnPxTseOTP9GGJSDvwcDCbzsgAvm4gjLsUQ5BYvgRy7olK9BlupLmAKlyBjZPMyExjIIP2PCAkdu63hW8EFi4PfTMG%2BJCviGB8mt5dfgwtWHOUa%2FvcLBgeyjeLpsroQGag%3D%3D',
#    'itemLocation': {'postalCode': '078**', 'country': 'US'},
#    'adultOnly': False,
#    'legacyItemId': '389507354687',
#    'availableCoupons': False,
#    'itemOriginDate': '2026-01-17T19:19:02.000Z',
#    'itemCreationDate': '2026-01-17T19:19:02.000Z',
#    'topRatedBuyingExperience': False,
#    'priorityListing': True,
#    'listingMarketplaceId': 'EBAY_US'},
#   {'itemId': 'v1|389507359562|0',
#    'title': '(PRE ORDER) Lionel Reading Legavy T1 #2100',
#    'leafCategoryIds': ['262303'],
#    'categories': [{'categoryId': '262303', 'categoryName': 'Locomotives'},
#     {'categoryId': '220', 'categoryName': 'Toys & Hobbies'},
#     {'categoryId': '180250', 'categoryName': 'Model Railroads & Trains'},
#     {'categoryId': '262301', 'categoryName': 'Railroads & Trains'}],
#    'image': {'imageUrl': 'https://i.ebayimg.com/images/g/VfYAAeSwfsZpa-Eu/s-l225.jpg'},
#    'price': {'value': '1.00', 'currency': 'USD'},
#    'itemHref': 'https://api.ebay.com/buy/browse/v1/item/v1%7C389507359562%7C0',
#    'seller': {'username': 'troystrainshop',
#     'feedbackPercentage': '100.0',
#     'feedbackScore': 610},
#    'condition': 'New',
#    'conditionId': '1000',
#    'thumbnailImages': [{'imageUrl': 'https://i.ebayimg.com/images/g/VfYAAeSwfsZpa-Eu/s-l1600.jpg'}],
#    'shippingOptions': [{'shippingCostType': 'FIXED',
#      'shippingCost': {'value': '0.00', 'currency': 'USD'},
#      'minEstimatedDeliveryDate': '2026-03-20T07:00:00.000Z',
#      'maxEstimatedDeliveryDate': '2026-04-14T07:00:00.000Z'}],
#    'buyingOptions': ['FIXED_PRICE'],
#    'itemWebUrl': 'https://www.ebay.com/itm/389507359562?_skw=lionel+reading+t1&hash=item5ab072a34a:g:VfYAAeSwfsZpa-Eu&amdata=enc%3AAQALAAAA8DZq0hFgvSYlgrFkWCFZ3z1VcVJnNp0QaBD0Nxvxr01Knkkm9dO6d2frTYzIu6DYvdy03uAwYgEcLOcbA%2F3b%2B8xeB%2FWRl42rEmWL8W1byi%2F0MsQgBLAkSaaMDve%2B6OJVLxOZ%2FBemVXe1EowsRTYgG7WnmgMt830PTJp0%2Fg70Jra4HkS8sLDD%2B3hWZ%2Fy9loi4s9xoVhtWqlawpuKQqxjCcVrVvGn0OUq%2Fb%2FQdFJwcHdtV3uOB7jHXinSnjm2xW5imRJHWzLe6LgLxKRezt7v6DlNkO%2F%2BK%2FkMV%2F9pNMK5oe9amVS9o1D5gGo40CTrRn7nBSQ%3D%3D',
#    'itemLocation': {'postalCode': '078**', 'country': 'US'},
#    'adultOnly': False,
#    'legacyItemId': '389507359562',
#    'availableCoupons': False,
#    'itemOriginDate': '2026-01-17T19:22:20.000Z',
#    'itemCreationDate': '2026-01-17T19:22:20.000Z',
#    'topRatedBuyingExperience': False,
#    'priorityListing': True,
#    'listingMarketplaceId': 'EBAY_US'}]}
